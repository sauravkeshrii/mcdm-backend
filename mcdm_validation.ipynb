# %%
import numpy as np
from mcdm_core import merec, topsis, mairca

# %%
X = np.array([
    [2.0410, 0.7306],
    [2.9280, 1.3441],
    [7.7040, 3.8894],
    [2.0690, 0.7992],
    [4.9203, 7.0694],
    [6.9297, 0.8136],
    [1.9653, 1.3978],
    [2.7713, 3.8204],
    [4.5630, 4.4114],
    [3.5677, 6.9694],
    [4.8410, 1.9435],
    [3.7227, 1.4282],
    [2.8693, 7.1003],
    [4.1257, 2.3283],
    [2.9090, 1.2479],
    [1.6743, 2.0881],
    [3.5653, 7.1046],
    [2.9523, 2.5645]
])

criteria_types = ["min", "max"]  # Ra(min), MRS(max)

# %%
w = merec(X, criteria_types)
w
# Out:
# array([0.47331064, 0.52668936])
